# %% [markdown]
# <br />
# <h1><center><font color='#800000 '><b>TP n°3 : Linear Regression</b></font>
# <br />
# </center></h1>

# %% [markdown]
# <br/>
# <h2><font size='6px' color='#660033'>Ghada Hirch</font><h2>

# %% [markdown]
# <h2><font color='#b33c00'>Exercice n° 1:</font></h2>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
ghada_hirch = pd.read_csv('grav.csv')
print("shape:", ghada_hirch.shape)
ghada_hirch.head()
# Out:
# shape: (7, 2)
#    height  seconds squared
# 0     100            8.967
# 1     120           11.989
# 2     150           15.852
# 3     180           16.991
# 4     200           20.284

# %%
X= ghada_hirch['height']
y= ghada_hirch['seconds squared']
plt.scatter(X ,y)
plt.xlabel("height")
plt.ylabel("seconds squared")
# Out:
# Text(0, 0.5, 'seconds squared')

# %%
np.corrcoef(X,y)
# Out:
# array([[1.        , 0.99473243],
#        [0.99473243, 1.        ]])

# %%
from scipy import stats

slope, intercept, r_value, p_value, std_err = stats.linregress(X,y)

print('Slope: ',slope,'\nIntercept: ',intercept)
# Out:
# Slope:  0.1028091251175917
# Intercept:  -0.6801232361241709

# %%
from scipy import stats
#linregress(): calcule la regression linéaire
#On s'interesse au slope et intercept
slope, intercept, r_value, p_value, std_err = stats.linregress(X, y)
def predict(x):
    return slope * x + intercept
#fitLine:prendre des valeurs prédites depuis X
fitLine = predict(X)
plt.plot(X, fitLine, c='y')

# %%
from matplotlib import pyplot as plt
plt.scatter(X, fitLine)
plt.plot(X, fitLine,'y')
plt.show()

# %% [markdown]
# <h2><font color='#b33c00'>Exercice n° 2:</font></h2>

# %%
# !pip install pyreadstat

# %%
# Import the numpy and pandas package, pyreadstat
import numpy as np
import pandas as pd
import pyreadstat
# Read the given sav file, and view some sample records
ghada_hirch, meta = pyreadstat.read_sav('test_scores.sav')
ghada_hirch
# Out:
#      school  school_setting  school_type classroom  teaching_method  \
# 0     ANKYI             1.0          2.0       6OL              0.0
# 1     ANKYI             1.0          2.0       6OL              0.0
# 2     ANKYI             1.0          2.0       6OL              0.0
# 3     ANKYI             1.0          2.0       6OL              0.0
# 4     ANKYI             1.0          2.0       6OL              0.0
# ...     ...             ...          ...       ...              ...
# 2128  ZOWMK             1.0          1.0       ZBH              0.0
# 2129  ZOWMK             1.0          1.0       ZBH              0.0
# 2130  ZOWMK             1.0          1.0       ZBH              0.0
# 2131  ZOWMK             1.0          1.0       ZBH              0.0
# 2132  ZOWMK             1.0          1.0       ZBH              0.0
#
#       n_student student_id  gender  lunch  pretest  posttest
# 0          20.0      2FHT3     1.0    2.0     62.0      72.0
# ...

# %%
# Shape of our dataset
ghada_hirch.shape

# Info our dataset
ghada_hirch.info()

# Describe our dataset
ghada_hirch.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2133 entries, 0 to 2132
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   school           2133 non-null   object
#  1   school_setting   2133 non-null   float64
#  2   school_type      2133 non-null   float64
#  3   classroom        2133 non-null   object
#  4   teaching_method  2133 non-null   float64
#  5   n_student        2133 non-null   float64
#  6   student_id       2133 non-null   object
#  7   gender           2133 non-null   float64
#  8   lunch            2133 non-null   float64
#  9   pretest          2133 non-null   float64
#  10  posttest         2133 non-null   float64
# dtypes: float64(8), object(3)
# memory usage: 183.4+ KB
#        school_setting  school_type  teaching_method    n_student       gender  \
# count     2133.000000  2133.000000      2133.000000  2133.000000  2133.000000
# ...

# %%
# Import matplotlib and seaborn libraries to visualize the data
import matplotlib.pyplot as plt 
import seaborn as sns

# Using pairplot we'll visualize the data for correlation
sns.pairplot(ghada_hirch, x_vars=['school','school_setting','school_type','classroom','teaching_method','n_student','student_id','gender', 'lunch','pretest'], 
             y_vars='posttest', size=4, aspect=1, kind='scatter')
plt.show()
# Out:
# C:\Users\My_Computing\anaconda3\lib\site-packages\seaborn\axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# Visualizing the data using heatmap
sns.heatmap(ghada_hirch.corr(), cmap="YlGnBu", annot = True)
plt.show()

# %%
# Creating X and y
X = ghada_hirch['pretest']
y = ghada_hirch['posttest']
plt.scatter(X,y)
plt.xlabel("pretest")
plt.ylabel("posttest")
# Out:
# Text(0, 0.5, 'posttest')

# %%
# Splitting the varaibles as training and testing
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7, 
                                                    test_size = 0.3, random_state = 100)

# %%
# Take a look at the train dataset
X_train
y_train
# Out:
# 1455    81.0
# 299     67.0
# 1912    49.0
# 863     92.0
# 298     64.0
#         ...
# 350     57.0
# 1930    53.0
# 79      79.0
# 1859    47.0
# 1544    89.0
# Name: posttest, Length: 1493, dtype: float64

# %%
# Importing Statsmodels.api library from Stamodel package
import statsmodels.api as sm
# Adding a constant to get an intercept
X_train_sm = sm.add_constant(X_train)
# Fitting the resgression line using 'OLS'
lr = sm.OLS(y_train, X_train_sm).fit()
# Printing the parameters
lr.params
# Out:
# const      13.374988
# pretest     0.978308
# dtype: float64

# %%
# Performing a summary to list out all the different parameters of the regression line fitted
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               posttest   R-squared:                       0.905
# Model:                            OLS   Adj. R-squared:                  0.905
# Method:                 Least Squares   F-statistic:                 1.429e+04
# Date:                Mon, 30 Nov 2020   Prob (F-statistic):               0.00
# Time:                        19:33:02   Log-Likelihood:                -4291.4
# No. Observations:                1493   AIC:                             8587.
# Df Residuals:                    1491   BIC:                             8597.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         13.3750      0.465     28.776      0.000      12.463      14.287
# ...

# %%
# Visualizing the regression line
plt.scatter(X_train, y_train)
plt.plot(X_train, 13.3750 + 0.9783*X_train, 'y')
plt.show()

# %%
# Predicting y_value using traingn data of X
y_train_pred = lr.predict(X_train_sm)
# Creating residuals from the y_train data and predicted y_data
res = (y_train - y_train_pred)
# Plotting the histogram using the residual values
fig = plt.figure()
sns.distplot(res, bins = 15)
plt.title('Error Terms', fontsize = 15)
plt.xlabel('y_train - y_train_pred', fontsize = 15)
plt.show()

# %%
# Looking for any patterns in the residuals
plt.scatter(X_train,res)
plt.show()

# %%
# Adding a constant to X_test
X_test_sm = sm.add_constant(X_test)
# Predicting the y values corresponding to X_test_sm
y_test_pred = lr.predict(X_test_sm)
# Printing the first 15 predicted values
y_test_pred
# Out:
# 686     58.377169
# 1836    58.377169
# 1587    88.704726
# 63      78.921643
# 1348    71.095177
#           ...
# 146     76.965027
# 374     51.529011
# 1989    75.986718
# 581     53.485628
# 272     64.247019
# Length: 640, dtype: float64

# %%
# Importing r2_square
from sklearn.metrics import r2_score
# Checking the R-squared value
r_squared = r2_score(y_test, y_test_pred)
r_squared
# Out:
# 0.9009451419275621

# %%
# Visualize the line on the test set
plt.scatter(X_test, y_test)
plt.plot(X_test, y_test_pred, 'y')
plt.show()

# %%
# Splitting the data into train and test
from sklearn.model_selection import train_test_split
X_train_lm, X_test_lm, y_train_lm, y_test_lm = train_test_split(X, y, train_size = 0.7, 
                                                                test_size = 0.3, random_state = 100)

# Shape of the train set without adding column
X_train_lm.shape
# Adding additional column to the train and test data
X_train_lm = X_train_lm.values.reshape(-1,1)
X_test_lm = X_test_lm.values.reshape(-1,1)
print(X_train_lm.shape)
print(X_test_lm.shape)
# Out:
# (1493, 1)
# (640, 1)

# %%
from sklearn.linear_model import LinearRegression
# Creating an object of Linear Regression
lm = LinearRegression()
# Fit the model using .fit() method
lm.fit(X_train_lm, y_train_lm)
# Intercept value
print("Intercept :",lm.intercept_)
# Slope value
print('Slope :',lm.coef_)
# Out:
# Intercept : 13.374988195767308
# Slope : [0.97830828]

# %%
# Making Predictions of y_value
y_train_pred = lm.predict(X_train_lm)
y_test_pred = lm.predict(X_test_lm)
# Comparing the r2 value of both train and test data
print(r2_score(y_train,y_train_pred))
print(r2_score(y_test,y_test_pred))
# Out:
# 0.9054961340673476
# 0.900945141927562

# %% [markdown]
# <h2><font color='#b33c00'>Exercice n° 3:</font></h2>

# %%
#loading the data
boston_dataset = pd.read_csv('housing.data.txt')
print("housing's shape : ", boston_dataset.shape)
#print the first rows of the data
boston_dataset.head()
# Out:
# housing's shape :  (506, 14)
#       CIRM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# <h3><font color='#007399'>1.Data preprocessing</font></h3>
# </br>

# %%
boston_dataset.isnull().sum()
# Out:
# CIRM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %% [markdown]
# <h3><font color='#007399'>2.Data Analysis</font></h3>
# </br>

# %%
print(boston_dataset.keys())
# Out:
# Index(['CIRM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
#plot the distribution of the target variable MEDV
sns.set()
sns.distplot(boston_dataset['MEDV'], bins=15)
plt.show()

# %%
# Visualizing the data using heatmap
sns.heatmap(boston_dataset.corr().round(2), cmap="YlGnBu", annot = True)
plt.show()

# %%
plt.figure()
features = ['LSTAT', 'RM']
target = boston_dataset['MEDV']
for i, col in enumerate(features):
    plt.subplot(1, len(features) , i+1)
    x = boston_dataset[col]
    y = target
    plt.scatter(x, y)
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('MEDV')

# %% [markdown]
# <h3><font color='#007399'>3.Preparing the data for training the model</font></h3>
# </br>

# %%
X = pd.DataFrame(np.c_[boston_dataset['LSTAT'], boston_dataset['RM']], columns = ['LSTAT','RM'])
y = boston_dataset['MEDV']

# %% [markdown]
# <h3><font color='#007399'>4.Splitting the data into training and testing sets</font></h3>
# </br>

# %%
# Splitting the data into train and test
from sklearn.model_selection import train_test_split
X_train_lm, X_test_lm, y_train_lm, y_test_lm = train_test_split(X, y, train_size = 0.7, 
                                                                test_size = 0.3, random_state = 100)

# Shape of the train set without adding column
X_train_lm.shape
# Adding additional column to the train and test data
X_train_lm = X_train_lm.values.reshape(-1,1)
X_test_lm = X_test_lm.values.reshape(-1,1)
print(X_train_lm.shape)
print(X_test_lm.shape)
# Out:
# (708, 1)
# (304, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=5)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (354, 2)
# (152, 2)
# (354,)
# (152,)

# %% [markdown]
# <h3><font color='#007399'>5.Training and testing the model</font></h3>
# </br>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
lm = LinearRegression()
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# <h3><font color='#007399'>6.Model evaluation</font></h3>
# </br>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
# model evaluation for training set
y_train_predict = lm.predict(X_train)
rmse = (np.sqrt(mean_squared_error(y_train, y_train_predict)))
r2 = r2_score(y_train, y_train_predict)

print("The model performance for training set:")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# model evaluation for testing set
y_test_predict = lm.predict(X_test)
rmse = (np.sqrt(mean_squared_error(y_test, y_test_predict)))
r2 = r2_score(y_test, y_test_predict)
print("The model performance for testing set:")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
# Out:
# The model performance for training set:
# --------------------------------------
# RMSE is 5.291267334085863
# R2 score is 0.6493177656003104
#
#
# The model performance for testing set:
# --------------------------------------
# RMSE is 6.041044703455955
# R2 score is 0.6162026947666575
